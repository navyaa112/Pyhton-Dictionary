# %% [markdown]
# <a href="https://colab.research.google.com/github/vikram018/Pyhton-Dictionary/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dictionary
name=input("Enter your name:")
print("Hello",name,"!Welcome to the Quiz")

print("Round-1")
q1="""Ques1: Semicolon at the end of each SQL Statement will terminate the SQL statement.
a.True
b.False"""
q2="""Ques2: SQL is NOT case insensitive.
a.True
b.False
"""
q3="""Ques3: The SELECT command, with its various clauses, allows users to query the data contained in the tables.
a.True
b.False
"""

questions={q1:"a",q2:"b",q3:"b"}
score=0
for i in questions:
    print(i)
    ans= input("Ans:")
    if ans==questions[i]:
        print("Congratulations,you got 1 point")
        score=score+1
    else:
        print("wrong answer,you lost 1 point")
        score=score-1
print("Round-2")
q1=="""Ques1: We can frame our own XML tags.
a.True
b.False"""
q2="""Ques2: XML is designed to self-destructive.
a.True
b.False"""
q3="""Ques3: XML is a W3C Recommendation
a.True
b.False"""

questions={q1:"b",q2:"a",q3:"a"}
for i in questions:
    print(i)
    ans=input("Ans:")
    if ans==questions[i]:
        print("Congratulations,you got 1 point")
        score=score+1
    else:
        print("wrong answer,you lost 1 point")
        score=score-1
print("Round-3")        
q1="""Ques1: Python is a case sensitive language.
a.True
b.False"""
q2="""Ques2: Python is object-oriented language.
a.True
b.False"""
q3="""Ques3: Python is a scripting language.
a.True
b.False"""

questions={q1:"b",q2:"a",q3:"b"}
for i in questions:
    print(i)
    ans=input("Ans:")
    if ans==questions[i]:
        print("Congratulations,you got 1 point")
        score=score+1
    else:
        print("wrong answer,you lost 1 point")
        score=score-1
        
print("Round-4")

q1="""Ques1: Can we hide content using the comment in HTML?
a.True
b.False"""
q2="""Ques2: Can we hide inline content using the comment in HTML?
a.True
b.False"""
q3="""Ques3: Nested HTML Elements are allowed in HTML?
a.True
b.False"""

questions={q1:"a",q2:"a",q3:"a"}
for i in questions:
    print(i)
    ans=input("Ans:")
    if ans==questions[i]:
        print("Congratulations,you got 1 point")
        score=score+1
    else:
        print("wrong answer,you lost 1 point")
        score=score-1

print("Round-5")

q1="""Ques1: Polymorphism is a feature of C++ where the same functions behave differently depending upon what they are operating on.
a.True
b.False"""
q2="""Ques2: Double data type takes 4 bytes in size.
a.True
b.False"""
q3="""Ques3: Break statement takes the control out of the switch statement.
a.True
b.False"""

questions={q1:"a",q2:"a",q3:"a"}
for i in questions:
    print(i)
    ans=input("Ans:")
    if ans==questions[i]:
        print("Congratulations,you got 1 point")
        score=score+1
    else:
        print("wrong answer,you lost 1 point")
        score=score-1
print("Final score is:",score)
